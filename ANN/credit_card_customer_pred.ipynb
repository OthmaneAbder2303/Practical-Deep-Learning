# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Churn_Modelling.csv')

df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
df.drop(columns=['RowNumber', 'CustomerId', 'Surname'], inplace=True)
df.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
df['Geography'].value_counts()
# Out:
# Geography
# France     5014
# Germany    2509
# Spain      2477
# Name: count, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      5457
# Female    4543
# Name: count, dtype: int64

# %% [markdown]
# we will perform one-hot-encoding for categorical variables {'geography', 'gender'}

# %%
df = pd.get_dummies(df, columns=['Geography', 'Gender'], drop_first=True)
df.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
# 3          699   39       1       0.00              2          0
# 4          850   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Exited  Geography_Germany  \
# 0               1        101348.88       1              False
# 1               1        112542.58       0              False
# 2               0        113931.57       1              False
# 3               0         93826.63       0              False
# 4               1         79084.10       0              False
#
#    Geography_Spain  Gender_Male
# 0            False        False
# 1             True        False
# 2            False        False
# 3            False        False
# 4             True        False

# %%
X = df.drop(columns=['Exited'])
y = df['Exited'].values

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_std = scaler.fit_transform(X_train)
X_test_std = scaler.transform(X_test)

# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input

# %%
model = Sequential([
    Input(shape=(11,)),
    Dense(11, activation='relu'),
    Dense(11, activation='relu'),
    Dense(1, activation='sigmoid')
])

# %%
model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_12 (Dense)                │ (None, 11)             │           132 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 11)             │           132 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 1)              │            12 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 276 (1.08 KB)
#  Trainable params: 276 (1.08 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(X_train_std, y_train, epochs=50, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 654us/step - accuracy: 0.6414 - loss: 0.6266 - val_accuracy: 0.8019 - val_loss: 0.4804
# Epoch 2/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 384us/step - accuracy: 0.8008 - loss: 0.4747 - val_accuracy: 0.8025 - val_loss: 0.4436
# Epoch 3/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 374us/step - accuracy: 0.8048 - loss: 0.4380 - val_accuracy: 0.8087 - val_loss: 0.4281
# Epoch 4/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 399us/step - accuracy: 0.8040 - loss: 0.4420 - val_accuracy: 0.8163 - val_loss: 0.4180
# Epoch 5/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 382us/step - accuracy: 0.8082 - loss: 0.4291 - val_accuracy: 0.8250 - val_loss: 0.4110
# Epoch 6/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 366us/step - accuracy: 0.8162 - loss: 0.4260 - val_accuracy: 0.8331 - val_loss: 0.4016
# Epoch 7/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 373us/step - accuracy: 0.8336 - loss: 0.3884 - val_accuracy: 0.8413 - val_loss: 0.3906
# Epoch 8/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 361us/step - accuracy: 0.8321 - loss: 0.3923 - val_accuracy: 0.8450 - val_loss: 0.3809
# Epoch 9/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 359us/step - accuracy: 0.8408 - loss: 0.3754 - val_accuracy: 0.8481 - val_loss: 0.3702
# Epoch 10/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 369us/step - accuracy: 0.8446 - loss: 0.3734 - val_accuracy: 0.8525 - val_loss: 0.3647
# Epoch 11/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 389us/step - accuracy: 0.8527 - loss: 0.3547 - val_accuracy: 0.8531 - val_loss: 0.3605
# Epoch 12/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 414us/step - accuracy: 0.8571 - loss: 0.3476 - val_accuracy: 0.8556 - val_loss: 0.3574
# Epoch 13/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 463us/step - accuracy: 0.8585 - loss: 0.3388 - val_accuracy: 0.8537 - val_loss: 0.3586
# Epoch 14/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 382us/step - accuracy: 0.8539 - loss: 0.3492 - val_accuracy: 0.8537 - val_loss: 0.3556
# Epoch 15/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 392us/step - accuracy: 0.8564 - loss: 0.3385 - val_accuracy: 0.8537 - val_loss: 0.3539
# Epoch 16/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 393us/step - accuracy: 0.8565 - loss: 0.3472 - val_accuracy: 0.8544 - val_loss: 0.3557
# Epoch 17/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 370us/step - accuracy: 0.8540 - loss: 0.3492 - val_accuracy: 0.8544 - val_loss: 0.3533
# Epoch 18/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 377us/step - accuracy: 0.8583 - loss: 0.3370 - val_accuracy: 0.8531 - val_loss: 0.3537
# Epoch 19/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step - accuracy: 0.8570 - loss: 0.3412 - val_accuracy: 0.8531 - val_loss: 0.3530
# Epoch 20/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 397us/step - accuracy: 0.8585 - loss: 0.3433 - val_accuracy: 0.8525 - val_loss: 0.3515
# Epoch 21/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 388us/step - accuracy: 0.8605 - loss: 0.3396 - val_accuracy: 0.8550 - val_loss: 0.3515
# Epoch 22/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 393us/step - accuracy: 0.8589 - loss: 0.3422 - val_accuracy: 0.8537 - val_loss: 0.3498
# Epoch 23/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 388us/step - accuracy: 0.8698 - loss: 0.3270 - val_accuracy: 0.8569 - val_loss: 0.3499
# Epoch 24/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 396us/step - accuracy: 0.8542 - loss: 0.3500 - val_accuracy: 0.8562 - val_loss: 0.3494
# Epoch 25/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 395us/step - accuracy: 0.8636 - loss: 0.3341 - val_accuracy: 0.8562 - val_loss: 0.3491
# Epoch 26/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 397us/step - accuracy: 0.8625 - loss: 0.3343 - val_accuracy: 0.8562 - val_loss: 0.3488
# Epoch 27/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 386us/step - accuracy: 0.8679 - loss: 0.3237 - val_accuracy: 0.8581 - val_loss: 0.3485
# Epoch 28/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 385us/step - accuracy: 0.8593 - loss: 0.3394 - val_accuracy: 0.8587 - val_loss: 0.3478
# Epoch 29/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step - accuracy: 0.8658 - loss: 0.3335 - val_accuracy: 0.8544 - val_loss: 0.3491
# Epoch 30/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 382us/step - accuracy: 0.8625 - loss: 0.3400 - val_accuracy: 0.8600 - val_loss: 0.3474
# Epoch 31/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 408us/step - accuracy: 0.8649 - loss: 0.3271 - val_accuracy: 0.8612 - val_loss: 0.3462
# Epoch 32/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 388us/step - accuracy: 0.8607 - loss: 0.3279 - val_accuracy: 0.8562 - val_loss: 0.3492
# Epoch 33/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 391us/step - accuracy: 0.8591 - loss: 0.3368 - val_accuracy: 0.8606 - val_loss: 0.3466
# Epoch 34/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 389us/step - accuracy: 0.8571 - loss: 0.3359 - val_accuracy: 0.8587 - val_loss: 0.3467
# Epoch 35/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 382us/step - accuracy: 0.8587 - loss: 0.3359 - val_accuracy: 0.8606 - val_loss: 0.3458
# Epoch 36/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step - accuracy: 0.8578 - loss: 0.3282 - val_accuracy: 0.8619 - val_loss: 0.3454
# Epoch 37/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step - accuracy: 0.8617 - loss: 0.3269 - val_accuracy: 0.8606 - val_loss: 0.3457
# Epoch 38/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 386us/step - accuracy: 0.8624 - loss: 0.3303 - val_accuracy: 0.8650 - val_loss: 0.3449
# Epoch 39/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 391us/step - accuracy: 0.8670 - loss: 0.3269 - val_accuracy: 0.8544 - val_loss: 0.3495
# Epoch 40/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 393us/step - accuracy: 0.8640 - loss: 0.3282 - val_accuracy: 0.8625 - val_loss: 0.3444
# Epoch 41/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 388us/step - accuracy: 0.8654 - loss: 0.3259 - val_accuracy: 0.8631 - val_loss: 0.3440
# Epoch 42/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 386us/step - accuracy: 0.8609 - loss: 0.3358 - val_accuracy: 0.8637 - val_loss: 0.3438
# Epoch 43/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step - accuracy: 0.8609 - loss: 0.3356 - val_accuracy: 0.8650 - val_loss: 0.3440
# Epoch 44/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 422us/step - accuracy: 0.8689 - loss: 0.3208 - val_accuracy: 0.8619 - val_loss: 0.3446
# Epoch 45/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 404us/step - accuracy: 0.8607 - loss: 0.3314 - val_accuracy: 0.8625 - val_loss: 0.3453
# Epoch 46/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 394us/step - accuracy: 0.8700 - loss: 0.3191 - val_accuracy: 0.8631 - val_loss: 0.3436
# Epoch 47/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 388us/step - accuracy: 0.8657 - loss: 0.3273 - val_accuracy: 0.8619 - val_loss: 0.3442
# Epoch 48/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 394us/step - accuracy: 0.8636 - loss: 0.3323 - val_accuracy: 0.8662 - val_loss: 0.3429
# Epoch 49/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 381us/step - accuracy: 0.8616 - loss: 0.3316 - val_accuracy: 0.8687 - val_loss: 0.3430
# Epoch 50/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 389us/step - accuracy: 0.8708 - loss: 0.3183 - val_accuracy: 0.8637 - val_loss: 0.3435

# %%
y_pred = model.predict(X_test_std)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 413us/step

# %%
y_pred
# Out:
# array([[0.1000586 ],
#        [0.07292081],
#        [0.06493811],
#        ...,
#        [0.03122159],
#        [0.05755312],
#        [0.58502775]], dtype=float32)

# %%
y_pred = (y_pred > 0.5).astype(int)  # threshold 0.5
y_pred
# Out:
# array([[0],
#        [0],
#        [0],
#        ...,
#        [0],
#        [0],
#        [1]])

# %%
from sklearn.metrics import accuracy_score

score = accuracy_score(y_test, y_pred)
score
# Out:
# 0.861

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, y_pred)
cm
sns.heatmap(cm, annot=True, fmt='d')
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
