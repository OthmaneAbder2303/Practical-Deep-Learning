# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('placement.csv')
print(df.shape)
df.head()
# Out:
# (100, 3)
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
sns.scatterplot(data=df, x='cgpa', y='resume_score', hue='placed')
plt.show()

# %%
X = df.iloc[:, :2].values
y = df.iloc[:,-1].values
print(X[:5])
print(y[:5])
# Out:
# [[8.14 6.52]
#  [6.17 5.17]
#  [8.27 8.86]
#  [6.88 7.27]
#  [7.52 7.3 ]]
# [1 0 1 1 1]

# %%
from sklearn.linear_model import Perceptron

model = Perceptron()
model.fit(X, y)
# Out:
# Perceptron()

# %%
model.coef_, model.intercept_
# Out:
# (array([[ 40.26, -36.  ]]), array([-25.]))

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X, y, clf=model)
# Out:
# /Users/othmaneabderrazik/Library/Python/3.9/lib/python/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /Users/othmaneabderrazik/Library/Python/3.9/lib/python/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /Users/othmaneabderrazik/Library/Python/3.9/lib/python/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# <Axes: >
